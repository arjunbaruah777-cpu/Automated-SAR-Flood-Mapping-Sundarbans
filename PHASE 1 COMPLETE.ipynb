# %%
import geopandas as gpd
import rasterio
import ee
import geemap

print("All GIS Libraries Successfully Loaded! Ready for Excellence.")
ee.Authenticate()
# Out:
# All GIS Libraries Successfully Loaded! Ready for Excellence.
# <p>To authorize access needed by Earth Engine, open the following
#         URL in a web browser and follow the instructions:</p>
# ...

# %%
# 0. Load our tools (Crucial step after a restart!)
import ee
import geemap

# 1. Turn on the Earth Engine API
ee.Initialize()

# 2. Create an interactive map canvas using geemap
Map = geemap.Map()

# 3. Define our NEW Area of Interest - Entire Sundarbans Delta (India & Bangladesh)
roi_lon = 89.2000
roi_lat = 21.9000

# 4. Center the map for the ~10,000 sqkm area.
Map.setCenter(roi_lon, roi_lat, 8)

# 5. Display the map right here in the notebook
Map
# Out:
# Map(center=[21.9, 89.2], controls=(WidgetControl(options=['position', 'transparent_bg'], position='topright', …
